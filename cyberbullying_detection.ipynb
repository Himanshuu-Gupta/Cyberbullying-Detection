# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive/')
os.chdir("./gdrive/My Drive/ALDA project/")
# Out:
# Mounted at /content/gdrive/

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/ALDA project

# %% [markdown]
# #Data Pre processing

# %% [markdown]
# ## Kaggle Dataset Cleaning

# %%
#kaggle_files = glob.glob("/kaggle_parsed_dataset.csv")
kaggle_df = pd.read_csv("./kaggle_parsed_dataset.csv")
kaggle_df['Source'] = kaggle_df.shape[0]*['kaggle_df']
kaggle_df.head()
# Out:
#    index  ...                                               Text
# 0      0  ...                               "You fuck your dad."
# 1      1  ...  "i really don't understand your point.\xa0 It ...
# 2      2  ...  "A\\xc2\\xa0majority of Canadians can and has ...
# 3      3  ...  "listen if you dont wanna get married to a man...
# 4      4  ...  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
#
# [5 rows x 4 columns]

# %%
kaggle_df.isna().sum()
# Out:
# index          0
# oh_label       0
# Date        1242
# Text           0
# dtype: int64

# %%
kaggle_df = kaggle_df.drop(['index', 'Date'], axis=1)

# %%
kaggle_df
# Out:
#       oh_label                                               Text
# 0            1                               "You fuck your dad."
# 1            0  "i really don't understand your point.\xa0 It ...
# 2            0  "A\\xc2\\xa0majority of Canadians can and has ...
# 3            0  "listen if you dont wanna get married to a man...
# 4            0  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
# ...        ...                                                ...
# 8794         0  "Never really gave it much thought. I just fig...
# 8795         0                 "Nadie se salva de la regla 34 xd"
# 8796         0               "Question: Are you a boy or a girl?"
# 8797         1  "Leave your email or phone number and maybe yo...
# 8798         0  "From the scenarios you present, I see you bel...
#
# [8799 rows x 2 columns]

# %% [markdown]
# ## Twitter Dataset Cleaning

# %%
twitter_df = pd.read_csv("./twitter_parsed_dataset.csv")
twitter_df['Source'] = twitter_df.shape[0]*['twitter_df']
twitter_df.head()
# Out:
#                    index                     id  ... Annotation oh_label
# 0  5.74948705591165E+017  5.74948705591165E+017  ...       none      0.0
# 1  5.71917888690393E+017  5.71917888690393E+017  ...       none      0.0
# 2  3.90255841338601E+017  3.90255841338601E+017  ...     sexism      1.0
# 3  5.68208850655916E+017  5.68208850655916E+017  ...     racism      1.0
# 4  5.75596338802373E+017  5.75596338802373E+017  ...       none      0.0
#
# [5 rows x 5 columns]

# %%
twitter_df
# Out:
#                        index                     id  ... Annotation oh_label
# 0      5.74948705591165E+017  5.74948705591165E+017  ...       none      0.0
# 1      5.71917888690393E+017  5.71917888690393E+017  ...       none      0.0
# 2      3.90255841338601E+017  3.90255841338601E+017  ...     sexism      1.0
# 3      5.68208850655916E+017  5.68208850655916E+017  ...     racism      1.0
# 4      5.75596338802373E+017  5.75596338802373E+017  ...       none      0.0
# ...                      ...                    ...  ...        ...      ...
# 16846  5.75606766236475E+017  5.75606766236475E+017  ...       none      0.0
# 16847  5.72333822886326E+017  5.72333822886326E+017  ...       none      0.0
# 16848  5.72326950057845E+017  5.72326950057845E+017  ...       none      0.0
# 16849  5.74799612642357E+017  5.74799612642357E+017  ...       none      0.0
# 16850  5.68826121153684E+017  5.68826121153684E+017  ...       none      0.0
#
# [16851 rows x 5 columns]

# %%
cyberbully = twitter_df[twitter_df.oh_label==1.0].count()[0]
nocyberbully = twitter_df[twitter_df.oh_label==0.0].count()[0]
value = [cyberbully,nocyberbully]
labels = ["cyberbully", "no-cyberbully"]
plt.bar(np.arange(len(value)),value);
plt.title("Comparison between number of cyberbully and nocyberbully text detected")
plt.xlabel("Labels")
plt.ylabel("Count")
plt.show()

# %%
twitter_df = twitter_df.drop(['index', 'id', 'Annotation'], axis=1)

# %%
twitter_df
# Out:
#                                                     Text  oh_label
# 0      @halalflaws @biebervalue @greenlinerzjm I read...       0.0
# 1      @ShreyaBafna3 Now you idiots claim that people...       0.0
# 2      RT @Mooseoftorment Call me sexist, but when I ...       1.0
# 3      @g0ssipsquirrelx Wrong, ISIS follows the examp...       1.0
# 4                                 #mkr No No No No No No       0.0
# ...                                                  ...       ...
# 16846  Feeling so sorry for the girls, they should be...       0.0
# 16847  #MKR 'pretty good dishes we're happy with' - O...       0.0
# 16848  RT @colonelkickhead: Deconstructed lemon tart!...       0.0
# 16849  @versacezaynx @nyazpolitics @greenlinerzjm You...       0.0
# 16850  And before you protest that you're *not* mad, ...       0.0
#
# [16851 rows x 2 columns]

# %% [markdown]
# ## Aggression Data Cleaning

# %%
aggression_df = pd.read_csv("./aggression_parsed_dataset.csv")
aggression_df['Source'] = aggression_df.shape[0]*['aggression_df']

# %%
aggression_df
# Out:
#          index  ... oh_label
# 0            0  ...        0
# 1            1  ...        0
# 2            2  ...        0
# 3            3  ...        0
# 4            4  ...        0
# ...        ...  ...      ...
# 115859  115859  ...        0
# 115860  115860  ...        0
# 115861  115861  ...        0
# 115862  115862  ...        0
# 115863  115863  ...        0
#
# [115864 rows x 5 columns]

# %%
aggression_df = aggression_df.drop(['ed_label_0', 'ed_label_1', 'index'], axis=1)

# %%
aggression_df
# Out:
#                                                      Text  ...         Source
# 0       `- This is not ``creative``.  Those are the di...  ...  aggression_df
# 1       `  :: the term ``standard model`` is itself le...  ...  aggression_df
# 2         True or false, the situation as of March 200...  ...  aggression_df
# 3        Next, maybe you could work on being less cond...  ...  aggression_df
# 4                    This page will need disambiguation.   ...  aggression_df
# ...                                                   ...  ...            ...
# 115859  `   These sources don't exactly exude a sense ...  ...  aggression_df
# 115860    The Institute for Historical Review is a pee...  ...  aggression_df
# 115861   :The way you're trying to describe it in this...  ...  aggression_df
# 115862    == Warning ==  There is clearly a protection...  ...  aggression_df
# 115863  Alternate option=== Is there perhaps enough ne...  ...  aggression_df
#
# [115864 rows x 3 columns]

# %% [markdown]
# ## Attack Dataset Cleaning

# %%
attack_df = pd.read_csv("./attack_parsed_dataset.csv")
attack_df['Source'] = attack_df.shape[0]*['attack_df']

# %%
attack_df
# Out:
#          index  ...     Source
# 0            0  ...  attack_df
# 1            1  ...  attack_df
# 2            2  ...  attack_df
# 3            3  ...  attack_df
# 4            4  ...  attack_df
# ...        ...  ...        ...
# 115859  115859  ...  attack_df
# 115860  115860  ...  attack_df
# 115861  115861  ...  attack_df
# 115862  115862  ...  attack_df
# 115863  115863  ...  attack_df
#
# [115864 rows x 6 columns]

# %%
attack_df = attack_df.drop(['ed_label_0', 'ed_label_1', 'index'], axis=1)

# %%
attack_df
# Out:
#                                                      Text  oh_label     Source
# 0       `- This is not ``creative``.  Those are the di...         0  attack_df
# 1       `  :: the term ``standard model`` is itself le...         0  attack_df
# 2         True or false, the situation as of March 200...         0  attack_df
# 3        Next, maybe you could work on being less cond...         0  attack_df
# 4                    This page will need disambiguation.          0  attack_df
# ...                                                   ...       ...        ...
# 115859  `   These sources don't exactly exude a sense ...         0  attack_df
# 115860    The Institute for Historical Review is a pee...         0  attack_df
# 115861   :The way you're trying to describe it in this...         0  attack_df
# 115862    == Warning ==  There is clearly a protection...         0  attack_df
# 115863  Alternate option=== Is there perhaps enough ne...         0  attack_df
#
# ...

# %% [markdown]
# ## Toxicity Data Cleaning

# %%
toxicity_df = pd.read_csv("./toxicity_parsed_dataset.csv")
toxicity_df['Source'] = toxicity_df.shape[0]*['toxicity_df']

# %%
toxicity_df
# Out:
#          index  ...       Source
# 0            0  ...  toxicity_df
# 1            1  ...  toxicity_df
# 2            2  ...  toxicity_df
# 3            3  ...  toxicity_df
# 4            4  ...  toxicity_df
# ...        ...  ...          ...
# 159681  159681  ...  toxicity_df
# 159682  159682  ...  toxicity_df
# 159683  159683  ...  toxicity_df
# 159684  159684  ...  toxicity_df
# 159685  159685  ...  toxicity_df
#
# [159686 rows x 6 columns]

# %%
n = len(pd.unique(toxicity_df['Text']))
print("Unique -", n)
print("Total -", toxicity_df.shape[0])
print("Duplicates", toxicity_df.shape[0] - n)
# Out:
# Unique - 159388
# Total - 159686
# Duplicates 298

# %%
check_df = toxicity_df[toxicity_df[['Text', 'oh_label']].duplicated(keep='last')]

# %%
checkcyberbully = check_df[check_df.oh_label==1.0].count()[0]
checknocyberbully = check_df[check_df.oh_label==0.0].count()[0]
print(checkcyberbully, checknocyberbully)
# Out:
# 14 283

# %%
toxicity_df[toxicity_df['Text']=="Hello, welcome to Wikipedia. Here are some useful links in case you haven't already found them:  *How to edit a page *How to write a great article *Naming conventions *Manual of Style  If you have any questions, see the help pages, add a question to the village pump or ask me on . I hope you enjoy editing here and being a Wikipedian!  Tip: you can sign your name with ~~~~    "]
# Out:
#       index  ...       Source
# 401     401  ...  toxicity_df
# 3016   3016  ...  toxicity_df
# 3019   3019  ...  toxicity_df
#
# [3 rows x 6 columns]

# %%
toxicity_df.iloc[1188]['Text']
# Out:
# 'Welcome!  Hello, and welcome to Wikipedia. Thank you for your contributions. I hope you like the place and decide to stay. Here are a few good links for newcomers:  *How to edit a page *Editing tutorial *Picture tutorial *How to write a great article *Naming conventions *Manual of Style  I hope you enjoy editing here and being a Wikipedian! By the way, you can sign your name on Talk and vote pages using three tildes, like this: ~~~. Four tildes (~~~~) produces your name and the current date. If you have any questions, see the help pages, add a question to the village pump or ask me on my Talk page. Again, welcome!   |  '

# %%
toxicity_df = toxicity_df.drop(['ed_label_0', 'ed_label_1', 'index'], axis=1)

# %%
toxicity_df
# Out:
#                                                      Text  ...       Source
# 0       This: :One can make an analogy in mathematical...  ...  toxicity_df
# 1       `  :Clarification for you  (and Zundark's righ...  ...  toxicity_df
# 2                               Elected or Electoral? JHK  ...  toxicity_df
# 3       `This is such a fun entry.   Devotchka  I once...  ...  toxicity_df
# 4       Please relate the ozone hole to increases in c...  ...  toxicity_df
# ...                                                   ...  ...          ...
# 159681  `   These sources don't exactly exude a sense ...  ...  toxicity_df
# 159682    The Institute for Historical Review is a pee...  ...  toxicity_df
# 159683   :The way you're trying to describe it in this...  ...  toxicity_df
# 159684    == Warning ==  There is clearly a protection...  ...  toxicity_df
# 159685  Alternate option=== Is there perhaps enough ne...  ...  toxicity_df
#
# [159686 rows x 3 columns]

# %% [markdown]
# ## Youtube Data Cleaning

# %%
youtube_df = pd.read_csv("./youtube_parsed_dataset.csv")
youtube_df['Source'] = youtube_df.shape[0]*['youtube_df']

# %%
youtube_df
# Out:
#       index UserIndex  ... oh_label      Source
# 0         0        X1  ...        0  youtube_df
# 1         1        X2  ...        0  youtube_df
# 2         2        X3  ...        1  youtube_df
# 3         3     X2218  ...        1  youtube_df
# 4         4        X5  ...        0  youtube_df
# ...     ...       ...  ...      ...         ...
# 3459   3464     X3465  ...        1  youtube_df
# 3460   3465     X3466  ...        0  youtube_df
# 3461   3466     X3467  ...        0  youtube_df
# 3462   3467     X3468  ...        0  youtube_df
# 3463   3468     X3469  ...        0  youtube_df
#
# [3464 rows x 11 columns]

# %%
youtube_df = youtube_df.drop(['index', 'UserIndex', 'Number of Comments', 'Number of Subscribers', 'Membership Duration', 'Number of Uploads', 'Profanity in UserID', 'Age'], axis=1)

# %%
youtube_df
# Out:
#                                                    Text  oh_label      Source
# 0     Does N.e.bodyelse Hear her Crazy ass Screamin ...         0  youtube_df
# 1     There are so many things that are incorrect wi...         0  youtube_df
# 2     3:26 hahah my boyfriend showed this song to me...         1  youtube_df
# 3     dick beyonce fuck y a ass hole you are truely ...         1  youtube_df
# 4     DongHaeTaemin and Kai ;A; luhansehun and bacon...         0  youtube_df
# ...                                                 ...       ...         ...
# 3459  She pretty I love this song I miss the old kel...         1  youtube_df
# 3460  Status-Online Im ZxkillergirlzX! I'm Zxkillerg...         0  youtube_df
# 3461  JR so cute EXO M Better I agree like yeah yeah...         0  youtube_df
# 3462                                                ! !         0  youtube_df
# 3463  great video and MERRY CHRISTMAS from greece :*...         0  youtube_df
#
# [3464 rows x 3 columns]

# %% [markdown]
# ## Merging all Data

# %%
final_df = pd.concat([kaggle_df, twitter_df, aggression_df, attack_df, toxicity_df, youtube_df])

# %%
final_df.shape
# Out:
# (420528, 3)

# %%
final_df.head()
# Out:
#    oh_label                                               Text     Source
# 0       1.0                               "You fuck your dad."  kaggle_df
# 1       0.0  "i really don't understand your point.\xa0 It ...  kaggle_df
# 2       0.0  "A\\xc2\\xa0majority of Canadians can and has ...  kaggle_df
# 3       0.0  "listen if you dont wanna get married to a man...  kaggle_df
# 4       0.0  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...  kaggle_df

# %% [markdown]
# ## EDA

# %%
final_df.isna().sum()
# Out:
# oh_label    3
# Text        1
# Source      0
# dtype: int64

# %%
master_df = final_df.dropna()

# %%
master_df.isna().sum()
# Out:
# oh_label    0
# Text        0
# Source      0
# dtype: int64

# %%
cyberbully = master_df[master_df.oh_label==1.0].count()[0]
nocyberbully = master_df[master_df.oh_label==0.0].count()[0]
value = [nocyberbully, cyberbully]
labels = [ "no-cyberbully", "cyberbully"]
plt.figure(figsize=(15,8))
plt.bar(np.arange(len(value)),value);
plt.title("Comparison between number of cyberbully and nocyberbully text detected")
plt.xlabel("Labels")
plt.ylabel("Count")
plt.show()
print(value)
print(cyberbully)
print(nocyberbully)
# Out:
# [368221, 52304]
# 52304
# 368221

# %%
n = len(pd.unique(master_df['Text']))
print("Unique -" , n)
print("Total -", master_df.shape[0])
print("Duplicates", master_df.shape[0] - n)
# Out:
# Unique - 225346
# Total - 420525
# Duplicates 195179

# %%
nondup_df = master_df.drop_duplicates(subset='Text', keep="first")
nondup_df = nondup_df[~(nondup_df['Text'].duplicated(keep=False))]

# %%
nondup_df
# Out:
#        index  ...                                               Text
# 0        0.0  ...                               "You fuck your dad."
# 1        1.0  ...  "i really don't understand your point.\xa0 It ...
# 4        4.0  ...  "C\xe1c b\u1ea1n xu\u1ed1ng \u0111\u01b0\u1edd...
# 5        5.0  ...  "@SDL OK, but I would hope they'd sign him to ...
# 6        6.0  ...                      "Yeah and where are you now?"
# ...      ...  ...                                                ...
# 8794  8794.0  ...  "Never really gave it much thought. I just fig...
# 8795  8795.0  ...                 "Nadie se salva de la regla 34 xd"
# 8796  8796.0  ...               "Question: Are you a boy or a girl?"
# 8797  8797.0  ...  "Leave your email or phone number and maybe yo...
# 8798  8798.0  ...  "From the scenarios you present, I see you bel...
#
# [7503 rows x 4 columns]

# %% [markdown]
# # Text Cleaning and Contraction Mapping

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
import re

# %%
final_df = pd.read_csv("./Final_merged_file.csv", index_col=None)

# %%
final_df
# Out:
#         Unnamed: 0  ...           Source
# 0                0  ...  k_suspicious_df
# 1                1  ...  k_suspicious_df
# 2                2  ...  k_suspicious_df
# 3                3  ...  k_suspicious_df
# 4                4  ...  k_suspicious_df
# ...            ...  ...              ...
# 278587      480523  ...      toxicity_df
# 278588      480524  ...      toxicity_df
# 278589      480525  ...      toxicity_df
# 278590      480526  ...      toxicity_df
# 278591      480527  ...      toxicity_df
#
# [278592 rows x 4 columns]

# %%
final_df = final_df.drop(['Source', 'Unnamed: 0'], axis=1)

# %%
final_df
# Out:
#                                                      Text  label
# 0       @switchfoot http://twitpic.com/2y1zl - Awww, t...      1
# 1       is upset that he can't update his Facebook by ...      1
# 2       @Kenichan I dived many times for the ball. Man...      1
# 3         my whole body feels itchy and like its on fire       0
# 4       @nationwideclass no, it's not behaving at all....      1
# ...                                                   ...    ...
# 278587  `   These sources don't exactly exude a sense ...      0
# 278588    The Institute for Historical Review is a pee...      0
# 278589   :The way you're trying to describe it in this...      0
# 278590    == Warning ==  There is clearly a protection...      0
# 278591  Alternate option=== Is there perhaps enough ne...      0
#
# [278592 rows x 2 columns]

# %% [markdown]
# ## Contraction Mapping

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    text = text.split() # to convert have'nt -> have not
    for i in range(len(text)):
        word = text[i]
        if word in contraction_mapping:
            text[i] = contraction_mapping[word]
    text = " ".join(text)
    #text = text.split()
    #newtext = []
    #for word in text:
    #    if word not in stop_words:
    #        newtext.append(word)
    #text = " ".join(newtext)
    text = text.replace("'s",'') # to convert your's -> your
    #text = re.sub(r'\(.*\)','',text) # remove (words)
    #text = re.sub(r'[^a-zA-Z0-9. ]','',text) # remove punctuations
    #text = re.sub(r'\.',' . ',text)
    return text

# %%
new_list_1 = []
# f = re.sub(r'[^a-zA-Z0-9. ]','',merged_df_2['Text'])
for text in final_df['Text']:
    new_list_1.append(expand_contractions(re.sub(r'[^a-zA-Z0-9. ]','',text)))
new_list_1
# Out:
# ['switchfoot httptwitpic.com2y1zl Awww thats a bummer. You shoulda got David Carr of Third Day to do it. D',
#  'is upset that he cant update his Facebook by texting it... and might cry as a result School today also. Blah',
#  'Kenichan I dived many times for the ball. Managed to save 50 The rest go out of bounds',
#  'my whole body feels itchy and like its on fire',
#  'nationwideclass no its not behaving at all. im mad. why am i here because I cant see you all over there.',
#  'Kwesidei not the whole crew',
#  'Need a hug',
#  'LOLTrish hey long time no see Yes.. Rains a bit only a bit LOL Im fine thanks hows you',
#  'TatianaK nope they didnt have it',
#  'twittera que me muera',
#  'spring break in plain city... its snowing',
#  'I just repierced my ears',
#  'caregiving I couldnt bear to watch it. And I thought the UA loss was embarrassing . . . . .',
#  'octolinz16 It it counts idk why I did either. you never talk to me anymore',
# ...

# %%
final_df['Updated_Text'] = new_list_1
final_df['Updated_Text'] = final_df['Updated_Text'].str.lower()

# %%
final_df
# Out:
#                                                      Text  ...                                       Updated_Text
# 0       @switchfoot http://twitpic.com/2y1zl - Awww, t...  ...  switchfoot httptwitpic.com2y1zl awww thats a b...
# 1       is upset that he can't update his Facebook by ...  ...  is upset that he cant update his facebook by t...
# 2       @Kenichan I dived many times for the ball. Man...  ...  kenichan i dived many times for the ball. mana...
# 3         my whole body feels itchy and like its on fire   ...     my whole body feels itchy and like its on fire
# 4       @nationwideclass no, it's not behaving at all....  ...  nationwideclass no its not behaving at all. im...
# ...                                                   ...  ...                                                ...
# 278587  `   These sources don't exactly exude a sense ...  ...  these sources dont exactly exude a sense of im...
# ...

# %%
final_df.shape
# Out:
# (278592, 3)

# %%
master_df = pd.DataFrame([final_df.Updated_Text, final_df.label]).transpose()

# %%
master_df = master_df.rename(columns={"Updated_Text": "text"})
master_df
# Out:
#                                                      text label
# 0       switchfoot httptwitpic.com2y1zl awww thats a b...     1
# 1       is upset that he cant update his facebook by t...     1
# 2       kenichan i dived many times for the ball. mana...     1
# 3          my whole body feels itchy and like its on fire     0
# 4       nationwideclass no its not behaving at all. im...     1
# ...                                                   ...   ...
# 278587  these sources dont exactly exude a sense of im...     0
# 278588  the institute for historical review is a peerr...     0
# 278589  the way youre trying to describe it in this ar...     0
# 278590  warning there is clearly a protectionist regim...     0
# 278591  alternate option is there perhaps enough newsw...     0
#
# [278592 rows x 2 columns]

# %% [markdown]
# ## Split into Training and Test

# %%
y = final_df.label
x = final_df.Updated_Text

# %%
train_data, test_data = train_test_split(master_df, test_size=0.2,
                                         random_state=7) # Splits Dataset into Training and Testing set
print("Train Data size:", len(train_data))
print("Test Data size", len(test_data))
# Out:
# Train Data size: 222873
# Test Data size 55719

# %%
train_data
# Out:
#                                                      text label
# 66626   bruciebabe maxblumenthal jews lived on 40 of t...     1
# 114360  armed forces of the philippine commonwealth i ...     0
# 276313  perhaps you should notify wpast. the thing is ...     0
# 148602  excuse me pardon me but i was accused of spamm...     0
# 51638                           just woke up from my nap.     1
# ...                                                   ...   ...
# 235075    you are a notorious troll and vandal too hrafn.     1
# 10742   httptwitpic.com3ivnu walker granny w.short sho...     1
# 49689                     listen to music guilty pleasure     1
# 189636  nationality and flags ok people lets calm this...     0
# 61615   axl roses voice is just so hot you have such b...     0
#
# [222873 rows x 2 columns]

# %% [markdown]
# # Vectorization of training dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vector = CountVectorizer(stop_words = 'english', lowercase = True)

# %%
CountVectorizer()
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
train_x = count_vector.fit_transform(x_train)

# %%
train_x.shape
# Out:
# (158150, 253077)

# %%
val_x = count_vector.transform(x_val)

# %%
val_x
# Out:
# <27909x253077 sparse matrix of type '<class 'numpy.int64'>'
# 	with 662959 stored elements in Compressed Sparse Row format>

# %%
val_x.shape
# Out:
# (27909, 253077)

# %%
test_x = count_vector.transform(x_test)

# %%
test_x.shape
# Out:
# (32834, 253077)

# %% [markdown]
# # Machine Learning Implementation

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(train_x, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_pred_KNN = knn.predict(test_x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-a5c0dc1c8ec4> in <module>()
# ----> 1 y_pred_KNN = knn.predict(test_x)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     171         X = check_array(X, accept_sparse='csr')
#     172
# --> 173         neigh_dist, neigh_ind = self.kneighbors(X)
#     174         classes_ = self.classes_
#     175         _y = self._y
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     641                 X, self._fit_X, reduce_func=reduce_func,
#     642                 metric=self.effective_metric_, n_jobs=n_jobs,
# --> 643                 **kwds))
#     644
#     645         elif self._fit_method in ['ball_tree', 'kd_tree']:
#
# ...

# %%
print('F1 Score:', metrics.f1_score(y_test, y_pred_KNN))
print('Accuracy Score:', metrics.accuracy_score(y_test, y_pred_KNN))
print('Precision score: ', metrics.precision_score(y_test, y_pred_KNN))
print('Recall score: ', metrics.recall_score(y_test, y_pred_KNN))
print('Confusion Matrix:', metrics.confusion_matrix(y_test, y_pred_KNN))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_KNN))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_KNN))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_KNN)))

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()
ada.fit(train_x, y_train)

# %%
y_pred_ada = ada.predict(test_x)

# %%
print('F1 Score:', metrics.f1_score(y_test, y_pred_ada))
print('Accuracy Score:', metrics.accuracy_score(y_test, y_pred_ada))
print('Precision score: ', metrics.precision_score(y_test, y_pred_ada))
print('Recall score: ', metrics.recall_score(y_test, y_pred_ada))
print('Confusion Matrix:', metrics.confusion_matrix(y_test, y_pred_ada))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ada))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ada))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ada)))

# %%
plt.scatter(y_test, y_pred_ada)
plt.xlabel('Actual Score')
plt.ylabel('Predicted Score')
plt.title('Actual vs Predicted Score')

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn import svm

# %%
svm_model = svm.SVC()
svm_model.fit(train_x, y_train)

# %%
y_pred_svm = svm_model.predict(test_x)

# %%
print('F1 Score:', metrics.f1_score(y_test, y_pred_svm))
print('Accuracy Score:', metrics.accuracy_score(y_test, y_pred_svm))
print('Precision score: ', metrics.precision_score(y_test, y_pred_svm))
print('Recall score: ', metrics.recall_score(y_test, y_pred_svm))
print('Confusion Matrix:', metrics.confusion_matrix(y_test, y_pred_svm))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_svm))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_svm))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svm)))

# %% [markdown]
# ##Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

BGC = BaggingClassifier()
BGC.fit(train_x,y_train)

# %%
y_pred_bgc = BGC.predict(test_x)

# %%
model = 'Bagging Classifier'
print('Accuracy for {} is {}'.format(model,round(accuracy_score(y_pred_bgc,y_test),3)))
print('F1 Score for {} is {}'.format(model,round(f1_score(y_pred_bgc,y_test),3)))
print('Precision Score for {} is {}'.format(model,round(precision_score(y_pred_bgc,y_test),3)))
print('Recall Score for {} is {}'.format(model,round(recall_score(y_pred_bgc,y_test),3)))

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
#LogisticRegression
LR = LogisticRegression()
LR.fit(train_x,y_train)

# %%
y_pred_lr = LR.predict(test_x)

# %%
model = 'Logistic Regression'
print('Accuracy for {} is {}'.format(model,round(accuracy_score(y_pred_lr,y_test),3)))
print('F1 Score for {} is {}'.format(model,round(f1_score(y_pred_lr,y_test),3)))
print('Precision Score for {} is {}'.format(model,round(precision_score(y_pred_lr,y_test),3)))
print('Recall Score for {} is {}'.format(model,round(recall_score(y_pred_lr,y_test),3)))

# %% [markdown]
# ##Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
#Multinomial NB
MNB = MultinomialNB()
MNB.fit(train_x,y_train)
y_pred = MNB.predict(test_x)

# %%
model = 'Naive Bayes'
print('Accuracy for {} is {}'.format(model,round(accuracy_score(y_pred,y_test),3)))
print('F1 Score for {} is {}'.format(model,round(f1_score(y_pred,y_test),3)))
print('Precision Score for {} is {}'.format(model,round(precision_score(y_pred,y_test),3)))
print('Recall Score for {} is {}'.format(model,round(recall_score(y_pred,y_test),3)))

# %% [markdown]
# # PreProcessing for Neural network

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
MAXLENGTH = 30

# %%
train_data
# Out:
#                                                      text label
# 66626   bruciebabe maxblumenthal jews lived on 40 of t...     1
# 114360  armed forces of the philippine commonwealth i ...     0
# 276313  perhaps you should notify wpast. the thing is ...     0
# 148602  excuse me pardon me but i was accused of spamm...     0
# 51638                           just woke up from my nap.     1
# ...                                                   ...   ...
# 235075    you are a notorious troll and vandal too hrafn.     1
# 10742   httptwitpic.com3ivnu walker granny w.short sho...     1
# 49689                     listen to music guilty pleasure     1
# 189636  nationality and flags ok people lets calm this...     0
# 61615   axl roses voice is just so hot you have such b...     0
#
# [222873 rows x 2 columns]

# %% [markdown]
# ## Tokenizer
#
# Creating Token sequences for train and test data

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data.text)

word_index = tokenizer.word_index
vocab_size = len(tokenizer.word_index) + 1
print("Vocabulary Size :", vocab_size)
# Out:
# Vocabulary Size : 305130

# %%
x_train = pad_sequences(tokenizer.texts_to_sequences(train_data.text),
                        maxlen = MAXLENGTH)
x_test = pad_sequences(tokenizer.texts_to_sequences(test_data.text),
                       maxlen = MAXLENGTH)

print("Training Shape:",x_train.shape)
print("Testing Shape:",x_test.shape)
# Out:
# Training Shape: (222873, 30)
# Testing Shape: (55719, 30)

# %%
labels = train_data.label.unique().tolist()
print(labels)
# Out:
# [1, 0]

# %%
y_train = train_data.label
y_train.shape
# Out:
# (222873,)

# %%
encoder = LabelEncoder()
encoder.fit(train_data.label.to_list())

y_train = encoder.transform(train_data.label.to_list())
y_test = encoder.transform(test_data.label.to_list())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (222873, 1)
# y_test shape: (55719, 1)

# %% [markdown]
# ## Glove Embeddings
#
# Glove Embeddings to identify word contexts

# %%
#!wget http://nlp.stanford.edu/data/glove.6B.zip
#!unzip glove.6B.zip

# %%
embeddings_index = {}
GLOVE_PATH = './glove.6B.300d.txt'
f = open(GLOVE_PATH)
for line in f:
  values = line.split()
  word = value = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' %len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
EMBEDDING_DIM = 300
LR = 1e-3
BATCH_SIZE = 1024
EPOCHS = 15

embedding_matrix = np.zeros((vocab_size, EMBEDDING_DIM))
for word, i in word_index.items():
  embedding_vector = embeddings_index.get(word)
  if embedding_vector is not None:
    embedding_matrix[i] = embedding_vector
embedding_layer = layers.Embedding(vocab_size,
                                          EMBEDDING_DIM,
                                          weights=[embedding_matrix],
                                          input_length=MAXLENGTH,
                                          trainable=False)

# %% [markdown]
# #Helper Functions for NN

# %%
## Function to plot the loss and accuracy
def plot_history(history):
	  # plot loss
    plt.title('Loss')
    plt.plot(history.history['loss'], color='blue', label='train')
    plt.plot(history.history['val_loss'], color='red', label='test')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'])
    plt.show()
    
    # plot accuracy
    plt.title('Accuracy')
    plt.plot(history.history['accuracy'], color='blue', label='train')
    plt.plot(history.history['val_accuracy'], color='red', label='test')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'])
    plt.show()

    #plot F1
    plt.title('F1 score')
    plt.plot(history.history['f1_m'], color='blue', label='train')
    plt.plot(history.history['val_f1_m'], color='red', label='test')
    plt.ylabel('F1 score')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'])
    plt.show()

    #plot Recall
    plt.title('Recall')
    plt.plot(history.history['recall'], color='blue', label='train')
    plt.plot(history.history['val_recall'], color='red', label='test')
    plt.ylabel('Recall')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'])
    plt.show()

# %% [markdown]
# # LSTM

# %%
import keras
from sklearn.metrics import log_loss, roc_auc_score, accuracy_score
from keras.losses import binary_crossentropy
from keras.metrics import binary_accuracy
from keras import backend as K
from keras.callbacks import *

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
    
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
      f1_m
]

# %%
sequence_input = Input(shape=(MAXLENGTH,), dtype='int32')
embedding_sequences = embedding_layer(sequence_input)
x = SpatialDropout1D(0.2)(embedding_sequences)
x = LSTM(64, dropout=0.2, recurrent_dropout=0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
lstm_model = tf.keras.Model(sequence_input, outputs)
# Out:
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
lstm_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy',
              metrics=[METRICS])

# %%
lstm_model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_8 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 30, 300)           91539000
# _________________________________________________________________
# spatial_dropout1d_7 (Spatial (None, 30, 300)           0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 64)                93440
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               33280
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# ...

# %%
lstm_history = lstm_model.fit(x_train, y_train, batch_size=512, epochs=15,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 436/436 [==============================] - 57s 131ms/step - loss: 0.3405 - tp: 42151.0000 - fp: 17952.0000 - tn: 145001.0000 - fn: 17769.0000 - accuracy: 0.8397 - precision: 0.7013 - recall: 0.7035 - auc: 0.9039 - prc: 0.7475 - f1_m: 0.7013 - val_loss: 0.2999 - val_tp: 12590.0000 - val_fp: 5588.0000 - val_tn: 35228.0000 - val_fn: 2313.0000 - val_accuracy: 0.8582 - val_precision: 0.6926 - val_recall: 0.8448 - val_auc: 0.9315 - val_prc: 0.8157 - val_f1_m: 0.7604
# Epoch 2/15
# 436/436 [==============================] - 56s 128ms/step - loss: 0.2971 - tp: 44555.0000 - fp: 14923.0000 - tn: 148030.0000 - fn: 15365.0000 - accuracy: 0.8641 - precision: 0.7491 - recall: 0.7436 - auc: 0.9285 - prc: 0.8152 - f1_m: 0.7453 - val_loss: 0.2751 - val_tp: 12530.0000 - val_fp: 4642.0000 - val_tn: 36174.0000 - val_fn: 2373.0000 - val_accuracy: 0.8741 - val_precision: 0.7297 - val_recall: 0.8408 - val_auc: 0.9424 - val_prc: 0.8487 - val_f1_m: 0.7805
# Epoch 3/15
# ...

# %% [markdown]
# Plot for first 15 epochs

# %%
plot_history(lstm_history)

# %% [markdown]
# # Conv1D + Bidirectional LSTM

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.layers import Bidirectional, LSTM, Dense, Input, Dropout, Conv1D, SpatialDropout1D
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
sequence_input = Input(shape=(MAXLENGTH,), dtype='int32')
embedding_sequences = embedding_layer(sequence_input)
x = SpatialDropout1D(0.2)(embedding_sequences)
x = Conv1D(64, 5, activation='relu')(x)
x = Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.2))(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(sequence_input, outputs)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy',
              metrics=[METRICS])
ReduceLROnPlateau = ReduceLROnPlateau(factor=0.1,
                                     min_lr = 0.01,
                                     monitor = 'val_loss',
                                     verbose = 1)

# %%
history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS,
                    validation_data=(x_test, y_test), callbacks=[ReduceLROnPlateau])
# Out:
# Epoch 1/15
# 218/218 [==============================] - 93s 249ms/step - loss: 0.3951 - tp: 18407.4612 - fp: 8262.4749 - tn: 74120.5982 - fn: 11841.5114 - accuracy: 0.8059 - precision: 0.6543 - recall: 0.5236 - auc: 0.8565 - prc: 0.6577 - f1_m: 0.5307 - val_loss: 0.2948 - val_tp: 12123.0000 - val_fp: 4681.0000 - val_tn: 36135.0000 - val_fn: 2780.0000 - val_accuracy: 0.8661 - val_precision: 0.7214 - val_recall: 0.8135 - val_auc: 0.9306 - val_prc: 0.8087 - val_f1_m: 0.7642
# Epoch 2/15
# 218/218 [==============================] - 53s 242ms/step - loss: 0.2985 - tp: 23030.1689 - fp: 7816.9635 - tn: 74439.0046 - fn: 7345.9087 - accuracy: 0.8647 - precision: 0.7444 - recall: 0.7584 - auc: 0.9281 - prc: 0.8082 - f1_m: 0.7504 - val_loss: 0.2795 - val_tp: 12316.0000 - val_fp: 4440.0000 - val_tn: 36376.0000 - val_fn: 2587.0000 - val_accuracy: 0.8739 - val_precision: 0.7350 - val_recall: 0.8264 - val_auc: 0.9403 - val_prc: 0.8423 - val_f1_m: 0.7776
# Epoch 3/15
# ...

# %%
plot_history(history)

# %% [markdown]
# #Bidirectional LSTM

# %%
sequence_input = Input(shape=(MAXLENGTH,), dtype='int32')
embedding_sequences = embedding_layer(sequence_input)
x = SpatialDropout1D(0.2)(embedding_sequences)
x = Bidirectional(LSTM(64, dropout=0.2, recurrent_dropout=0.2))(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
bidir_model = tf.keras.Model(sequence_input, outputs)
# Out:
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
bidir_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy',
              metrics=[METRICS])

# %%
bidir_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 30, 300)           91539000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 30, 300)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               186880
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# ...

# %%
bidir_history = bidir_model.fit(x_train, y_train, batch_size=512, epochs=EPOCHS,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 436/436 [==============================] - 110s 239ms/step - loss: 0.2668 - tp: 35774.8375 - fp: 10303.4256 - tn: 112516.4737 - fn: 9249.4485 - accuracy: 0.8839 - precision: 0.7753 - recall: 0.7991 - auc: 0.9449 - prc: 0.8549 - f1_m: 0.7758 - val_loss: 0.2499 - val_tp: 12024.0000 - val_fp: 3304.0000 - val_tn: 37512.0000 - val_fn: 2879.0000 - val_accuracy: 0.8890 - val_precision: 0.7844 - val_recall: 0.8068 - val_auc: 0.9504 - val_prc: 0.8732 - val_f1_m: 0.7949
# Epoch 2/15
# 436/436 [==============================] - 99s 227ms/step - loss: 0.2521 - tp: 23832.5240 - fp: 6287.1167 - tn: 75719.2449 - fn: 6286.2998 - accuracy: 0.8880 - precision: 0.7905 - recall: 0.7928 - auc: 0.9494 - prc: 0.8683 - f1_m: 0.7910 - val_loss: 0.2467 - val_tp: 12239.0000 - val_fp: 3381.0000 - val_tn: 37435.0000 - val_fn: 2664.0000 - val_accuracy: 0.8915 - val_precision: 0.7835 - val_recall: 0.8212 - val_auc: 0.9525 - val_prc: 0.8783 - val_f1_m: 0.8014
# Epoch 3/15
# ...

# %%
plot_history(bidir_history)

# %% [markdown]
# # Tuning - Bidirectional LSTM

# %%
sequence_input = Input(shape=(MAXLENGTH,), dtype='int32')
embedding_sequences = embedding_layer(sequence_input)
x = SpatialDropout1D(0.2)(embedding_sequences)
x = Bidirectional(LSTM(128, dropout=0.1, recurrent_dropout=0.2))(x)
x = Dense(50, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(25, activation='relu')(x)
outputs = Dense(1, activation='sigmoid')(x)
stacked_bidir_model = tf.keras.Model(sequence_input, outputs)
# Out:
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
stacked_bidir_model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_10 (InputLayer)        [(None, 30)]              0
# _________________________________________________________________
# embedding (Embedding)        (None, 30, 300)           91539000
# _________________________________________________________________
# spatial_dropout1d_9 (Spatial (None, 30, 300)           0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dense_27 (Dense)             (None, 50)                12850
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 25)                1275
# ...

# %%
stacked_bidir_model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy',
              metrics=[METRICS])

# %%
stacked_bidir_history = stacked_bidir_model.fit(x_train, y_train, batch_size=512, epochs=10,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 436/436 [==============================] - 106s 229ms/step - loss: 0.3775 - tp: 32169.7231 - fp: 11825.1991 - tn: 111038.1854 - fn: 12811.0778 - accuracy: 0.8552 - precision: 0.7360 - recall: 0.7165 - auc: 0.9081 - prc: 0.7782 - f1_m: 0.6083 - val_loss: 0.2809 - val_tp: 11600.0000 - val_fp: 3644.0000 - val_tn: 37172.0000 - val_fn: 3303.0000 - val_accuracy: 0.8753 - val_precision: 0.7610 - val_recall: 0.7784 - val_auc: 0.9379 - val_prc: 0.8334 - val_f1_m: 0.7686
# Epoch 2/10
# 436/436 [==============================] - 99s 227ms/step - loss: 0.2899 - tp: 22846.0618 - fp: 7127.0275 - tn: 74808.5812 - fn: 7343.5149 - accuracy: 0.8695 - precision: 0.7591 - recall: 0.7555 - auc: 0.9325 - prc: 0.8226 - f1_m: 0.7565 - val_loss: 0.2588 - val_tp: 11596.0000 - val_fp: 3109.0000 - val_tn: 37707.0000 - val_fn: 3307.0000 - val_accuracy: 0.8849 - val_precision: 0.7886 - val_recall: 0.7781 - val_auc: 0.9466 - val_prc: 0.8600 - val_f1_m: 0.7826
# Epoch 3/10
# ...

# %%
plot_history(stacked_bidir_history)
